# %%
import pandas as pd

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#         fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 0   98.957239         0   28          0           0              0
# 1  100.028309         0   70          0          -1              0
# 2   98.693116         1   39          0           0              1
# 3  101.434123         1   14          1          -1              1
# 4   99.806413         0   66          1           0              1

# %%
df.tail()
# Out:
#            fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 2494   99.103635         1   22          1          -1              0
# 2495  101.267791         1   73          1           0              0
# 2496  101.758005         0   28          0           0              0
# 2497   99.497942         1   73          1           1              0
# 2498  101.639914         0    2          0          -1              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 6 columns):
# fever            2499 non-null float64
# bodyPain         2499 non-null int64
# age              2499 non-null int64
# runnyNose        2499 non-null int64
# diffBreath       2499 non-null int64
# infectionProb    2499 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 117.2 KB

# %%
df['fever'].value_counts()
# Out:
# 100.938833    1
# 100.891749    1
# 98.345563     1
# 101.994483    1
# 101.242500    1
# 101.947085    1
# 100.553833    1
# 99.524835     1
# 100.461505    1
# 101.710278    1
# 98.836250     1
# 101.992431    1
# 101.155596    1
# 100.381382    1
# 100.095262    1
# 99.621409     1
# 99.625221     1
# 101.913948    1
# 100.432229    1
# 100.035204    1
# 99.022151     1
# 98.952954     1
# 101.681021    1
# 100.591181    1
# 98.166730     1
# 98.776969     1
# 101.219264    1
# 100.920411    1
# 99.903981     1
# 98.548818     1
#              ..
# 98.709247     1
# 101.510410    1
# 101.253349    1
# 98.925236     1
# 100.860215    1
# 98.434246     1
# 100.907420    1
# 101.832154    1
# 101.731842    1
# 101.198404    1
# 99.182839     1
# 101.734316    1
# 99.210334     1
# 99.736505     1
# 98.570277     1
# 100.254139    1
# 100.655337    1
# 100.612337    1
# 101.700722    1
# 98.153400     1
# 101.867821    1
# 99.200401     1
# 100.400994    1
# 101.280702    1
# 99.892960     1
# 101.028415    1
# 100.559907    1
# 100.924639    1
# 101.305708    1
# 99.753199     1
# Name: fever, Length: 2499, dtype: int64

# %%
df['diffBreath'].value_counts()
# Out:
#  0    856
# -1    840
#  1    803
# Name: diffBreath, dtype: int64

# %%
df.describe()
# Out:
#              fever     bodyPain          age    runnyNose   diffBreath  \
# count  2499.000000  2499.000000  2499.000000  2499.000000  2499.000000
# mean    100.014375     0.505402    50.244498     0.484994    -0.014806
# std       1.140386     0.500071    29.087907     0.499875     0.810868
# min      98.000555     0.000000     1.000000     0.000000    -1.000000
# 25%      99.049355     0.000000    24.000000     0.000000    -1.000000
# 50%     100.009925     1.000000    50.000000     0.000000     0.000000
# 75%     101.001266     1.000000    76.000000     1.000000     1.000000
# max     101.999881     1.000000   100.000000     1.000000     1.000000
#
#        infectionProb
# count    2499.000000
# mean        0.512205
# std         0.499951
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# # TRAIN TEST SPLITTING

# %%
import numpy as np

# %%
def data_split(data,ratio):        # takes 2 values
    np.random.seed(42)          # random values are freezed
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
np.random.permutation(7)
# Out:
# array([4, 6, 1, 0, 2, 3, 5])

# %%
train, test = data_split(df, 0.3)

# %%
train
# Out:
#            fever  bodyPain  age  runnyNose  diffBreath  infectionProb
#
# 1871  100.556085         1   36          0          -1              1
# 786   100.074865         0   76          1           1              0
# 1530   99.490462         0   31          0           0              0
# 485   100.227804         0   47          1           0              1
# 2471  101.416293         1   71          0           0              0
# 134   100.226464         1   79          1           0              1
# 1538  101.318408         1   40          0           0              0
# 1352  101.878255         0   78          1           1              0
# 1922  100.569437         1   40          0           1              1
# 1279  100.497107         0   43          0           1              1
# 246   100.335070         1   72          1           1              0
# 1547   99.453182         0   73          0           0              1
# 789   100.953831         1   81          1          -1              1
# 259   100.858118         0   84          0          -1              1
# 422    98.747819         0   42          0           1              1
# ...          ...       ...  ...        ...         ...            ...
# 2239   98.950346         1   81          1           1              0
# 1080   98.811658         1   29          0          -1              1
# 881    99.956557         1   92          0          -1              1
# 382   100.513473         0    6          1           1              1
# 1604   99.286388         0   80          0           0              1
# 1621  101.028415         0   13          1           1              1
# 727    98.515136         1    4          1          -1              0
# 845    99.030768         0   83          1           0              1
# 2436   98.433896         1    8          0          -1              1
# 1041   98.848661         0   34          0           0              1
# 263    99.454477         0   18          1           1              0
# 1406   99.918420         0   73          1           0              1
# 2158  101.563269         1   83          1           0              1
# 2485  101.386921         1   80          0           1              0
# 415    98.716930         1   32          0          -1              1
# 929    98.565923         0   41          0           0              1
# 358   100.427988         1   17          1          -1              0
# 1177  101.730607         0   35          0           1              0
# 8     100.667932         1   59          0          -1              1
# 1657  101.055257         1   33          0           1              0
# 316   101.783670         0   81          1           0              1
# 304    99.947483         0   27          1           1              0
# 427   100.467750         1   10          1           1              1
# 105   101.013536         1   37          1           0              0
# 1490   98.934585         1   82          1          -1              1
# 121   101.790701         1   61          0           1              0
# 2194  100.118588         1   38          1          -1              1
# 1550  100.384038         0   95          1           1              0
# 1901  100.898813         1   82          1           0              0
# 2263  101.253349         0   45          1           1              0
#
# [749 rows x 6 columns]

# %%
X_train = train[['fever','bodyPain','age','runnyNose','diffBreath']].values
X_test = test[['fever','bodyPain','age','runnyNose','diffBreath']].values

# %%
Y_train = train[['infectionProb']].values.reshape(1750,)
Y_test = test[['infectionProb']].values.reshape(749,)

# %%
X_train
# Out:
# array([[100.1400257 ,   0.        ,  54.        ,   0.        ,
#          -1.        ],
#        [ 99.08808732,   1.        ,  47.        ,   1.        ,
#          -1.        ],
#        [101.8059387 ,   0.        ,  27.        ,   1.        ,
#           0.        ],
#        ...,
#        [101.9366661 ,   0.        ,  22.        ,   0.        ,
#          -1.        ],
#        [ 99.84479043,   1.        ,   1.        ,   0.        ,
#          -1.        ],
#        [101.0624076 ,   0.        ,  13.        ,   1.        ,
#           0.        ]])

# %%
Y_train
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
clf.predict([[100,1,22,1,1]])
# Out:
# array([1], dtype=int64)

# %%
clf.predict_proba([[100,1,22,1,1]])
# Out:
# array([[0.46315081, 0.53684919]])

# %%
inputFeatures = [102,1 ,22,-1,1]
inf_Prob = clf.predict_proba([inputFeatures])[0][1]

# %%
inf_Prob
# Out:
# 0.47805338024160104
